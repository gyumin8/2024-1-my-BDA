# %% [markdown]
# <a href="https://colab.research.google.com/github/gyumin8/2024-1-my-BDA/blob/main/inclass/03w_0325_mom_ch05_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns

print(sys.version)
print(pd.__version__)
print(np.__version__)
print(sns.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.5.3
# 1.25.2
# 0.13.1

# %% [markdown]
# #코랩에서 한글처리

# %%
# !pip install koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 46.0 MB/s eta 0:00:00
# ...

# %%
# %config InlineBackend.figure_format='retina'

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-10, 5, -3, 1])
plt.title('그래프 제목')
# Out:
# Text(0.5, 1.0, '그래프 제목')

# %% [markdown]
# #05 데이터 분석 기초! - 데이터 파악하기, 다루기 쉽게 수정하기

# %% [markdown]
# | 함수 | 기능 |
# |------|------|
# |head()|앞부분 출력 |
# |tail()|뒷부분 출력 |
# |shape| 행, 열 개수 출력|
# |info()| 변수 속성 출력|
# |descrive()| 요약 통계량 출력|

# %%
# !git clone https://github.com/ai7dn/2024-1-BDA.git
# Out:
# Cloning into '2024-1-BDA'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 4.00 MiB | 5.98 MiB/s, done.

# %%
exam = pd.read_csv('data/exam.csv')

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
exam.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.head(10)
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25
# 8   9       3    20       98       15
# 9  10       3    50       98       45

# %%
exam.shape
# Out:
# (20, 5)

# %%
exam.describe()
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# ##mpg 데이터 파악하기

# %%
mpg=pd.read_csv('data/mpg.csv')

# %%
mpg.head(8)
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4         audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5         audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6         audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7         audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
#
#   category
# 0  compact
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact
# 6  compact
# 7  compact

# %%
mpg.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.sample(10)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 145       nissan               altima    3.5  2008    6  manual(m6)   f   19
# 42         dodge          caravan 2wd    3.3  2008    6    auto(l4)   f   17
# 212   volkswagen                jetta    1.9  1999    4  manual(m5)   f   33
# 224   volkswagen           new beetle    2.0  1999    4    auto(l4)   f   19
# 161       subaru         forester awd    2.5  2008    4  manual(m5)   4   20
# 68         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4   12
# 18     chevrolet   c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 218   volkswagen                jetta    2.5  2008    5  manual(m5)   f   21
# 95          ford              mustang    4.6  1999    8  manual(m5)   r   15
# 188       toyota         camry solara    2.4  2008    4  manual(m5)   f   21
#
#      hwy fl    category
# 145   27  p     midsize
# 42    24  r     minivan
# 212   44  d     compact
# ...

# %%
mpg.info() ##옆에 인덱스 표현
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.describe(include="all")
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %%
mpg[["category"]]
# Out:
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 1 columns]

# %%
mpg[["category"]].describe()
# Out:
#        category
# count       234
# unique        7
# top         suv
# freq         62

# %% [markdown]
# #범주형 데이터
#
# - 명목형
# - 순서형

# %%
mpg.fl.unique()
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg["fl"].unique() # 연료 종류
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg.fl.value_counts()
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_index()
# Out:
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-12337ebcc082> in <cell line: 1>()
# ----> 1 mpg.fl.value_counts().sort_index().type()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
mpg.fl.value_counts().sort_index(ascending=False)
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_index(ascending=True)
# Out:
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_values()
# Out:
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_values(ascending=False)
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg[["fl","category"]].value_counts().to_frame()
# Out:
#                 0
# fl category
# r  suv         48
#    pickup      30
#    subcompact  29
#    midsize     26
#    compact     25
# p  compact     21
#    midsize     15
# r  minivan     10
# p  suv          8
#    2seater      5
# e  suv          4
# p  subcompact   3
# e  pickup       3
# d  suv          2
#    subcompact   2
#    compact      1
# e  minivan      1
# c  subcompact   1

# %%
mpg[["fl","category"]].value_counts("fl",ascending=False).to_frame()
# Out:
#       0
# fl
# r   168
# p    52
# e     8
# d     5
# c     1

# %%
mpg[["fl","category"]].value_counts().to_frame()

# %% [markdown]
# #함수와 메서드 차이 알아보기
#
# - 함수(내장함수)
# - 메소드
# - 패키지 함수

# %%
df=pd.DataFrame({'x':[1,2,3]})
df.head()
# Out:
#    x
# 0  1
# 1  2
# 2  3

# %% [markdown]
# ---

# %% [markdown]
# ## 05-2 변수명 바꾸기(p113): 시험 예상

# %%
df_raw=pd.DataFrame({'var1' : [1,2,1],
                     'var2' : [2,3,2],
                     'var2' : [10,20,30]})

df_raw
# Out:
#    var1  var2
# 0     1    10
# 1     2    20
# 2     1    30

# %%
df_new = df_raw
df_new
# Out:
#    var1  var2
# 0     1    10
# 1     2    20
# 2     1    30

# %%
df_new.rename(columns = {'var2' : 'v2'})
# Out:
#    var1  v2
# 0     1  10
# 1     2  20
# 2     1  30

# %%
df_raw
# Out:
#    var1  var2
# 0     1    10
# 1     2    20
# 2     1    30

# %%
df_new
# Out:
#    var1  var2
# 0     1    10
# 1     2    20
# 2     1    30

# %%
df_new = df_new.rename(columns = {'var2' : 'v2'})

# %%
df_new
# Out:
#    var1  v2
# 0     1  10
# 1     2  20
# 2     1  30

# %%
df_new.rename(columns = {'var2' : 'v2'}, inplace=True)
df_new
# Out:
#    var1  v2
# 0     1  10
# 1     2  20
# 2     1  30

# %%
df_new.rename(index={0: "x", 1: "y", 2: "z"}, inplace=True)
df_new
# Out:
#    var1  v2
# x     1  10
# y     2  20
# z     1  30

# %%
df = pd.DataFrame({"A": [1,2,3], "B": [4,5,6]})
df.rename(columns={"A": "a", "B": "c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# #05-3 파생변수 만들기: 시험예상

# %%
df=pd.DataFrame({'var1' : [4,3,8],
                 'var2' : [2,6,1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1=df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df['var_sum'] = df['var1'] + df['var2']
df
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df['var_mean'] = (df['var1'] + df['var2']) / 2  # var_mean 파생변수 만들기
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df['var_mean']=df.mean()

# %%
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       NaN
# 1     3     6        9       NaN
# 2     8     1        9       NaN

# %%
df['var_mean'] = (df['var1'] + df['var2']) / 2  # var_mean 파생변수 만들기
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2= df.copy()
df2
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df.sum()
# Out:
# var1        15.0
# var2         9.0
# var_sum     24.0
# var_mean    12.0
# dtype: float64

# %%
df['var_mean'] = (df['var1'] + df['var2']) / len(df)  # var_mean 파생변수 만들기
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       2.0
# 1     3     6        9       3.0
# 2     8     1        9       3.0

# %%
df['var_mean'] = (df['var1'] + df['var2']) / 2  # var_mean 파생변수 만들기
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2.sum(1)
# Out:
# 0    15.0
# 1    22.5
# 2    22.5
# dtype: float64

# %%
df2['my_sum'] = df2.sum(axis='columns')

# %%
df2
# Out:
#    var1  var2  var_sum  var_mean  my_sum
# 0     4     2        6       3.0    15.0
# 1     3     6        9       4.5    22.5
# 2     8     1        9       4.5    22.5

# %%
df2["my_mean"]=df2[["var1","var2"]].mean(axis=1)
df2
# Out:
#    var1  var2  var_sum  var_mean  my_sum  my_mean
# 0     4     2        6       3.0    15.0      3.0
# 1     3     6        9       4.5    22.5      4.5
# 2     8     1        9       4.5    22.5      4.5

# %% [markdown]
# #mpg 통합 연비 변수 만들기

# %%
mpg= pd.read_csv('data/mpg.csv')
mpg.sample(8)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 162       subaru         forester awd    2.5  2008    4  manual(m5)   4   19
# 7           audi           a4 quattro    1.8  1999    4  manual(m5)   4   18
# 230   volkswagen               passat    2.0  2008    4  manual(m6)   f   21
# 30     chevrolet      k1500 tahoe 4wd    5.7  1999    8    auto(l4)   4   11
# 232   volkswagen               passat    2.8  1999    6  manual(m5)   f   18
# 72         dodge  ram 1500 pickup 4wd    5.7  2008    8    auto(l5)   4   13
# 175       toyota          4runner 4wd    3.4  1999    6    auto(l4)   4   15
# 204       toyota    toyota tacoma 4wd    3.4  1999    6    auto(l4)   4   15
#
#      hwy fl category
# 162   25  p      suv
# 7     26  p  compact
# 230   29  p  midsize
# 30    15  r      suv
# 232   26  p  midsize
# 72    17  r   pickup
# 175   19  r      suv
# 204   19  r   pickup

# %%
#통합 연비 변수(total)만들기, total == cty + hwy의 평균: 시험예상


mpg['total']=mpg['cty']+mpg['hwy']

# %%
mpg['mean']=mpg['total']/len(mpg)

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total      mean
# 0     47  0.200855
# 1     50  0.213675
# 2     51  0.217949
# 3     51  0.217949
# 4     42  0.179487

# %%
mpg['mpg_mean']=mpg[['cty','hwy']].mean(axis='columns')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total      mean  max  mpg_mean
# 0     47  0.200855  NaN      23.5
# 1     50  0.213675  NaN      25.0
# 2     51  0.217949  NaN      25.5
# 3     51  0.217949  NaN      25.5
# 4     42  0.179487  NaN      21.0

# %%
sum(mpg['total'])/len(mpg)
# Out:
# 40.2991452991453

# %%
mpg['total'].mean()
# Out:
# 40.2991452991453

# %% [markdown]
# ### 조건문을 활용해 파생변수 만들기

# %%
mpg['total'].describe() #
# Out:
# count    234.000000
# mean      40.299145
# std       10.100580
# min       21.000000
# 25%       31.000000
# 50%       41.000000
# 75%       47.000000
# max       79.000000
# Name: total, dtype: float64

# %%
mpg['total'].plot.hist();
# Out:
# <Axes: ylabel='Frequency'>

# %%
mpg['total'].plot(kind="hist", title= "히스토그램");

# %%
mpg['total'].plot(kind="line", title= "선형함수");

# %%
import seaborn as sns

sns.histplot(mpg, x=mpg.total);

# %%
sns.histplot(mpg, x=mpg.total);

# %% [markdown]
# # 2.합격 판정 변수 만들기

# %%
mpg['test']=np.where(mpg['total']>=40, 'pass','fail')
mpg.sample(100)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 100        honda               civic    1.6  1999    4    auto(l4)   f   24
# 155      pontiac          grand prix    3.8  1999    6    auto(l4)   f   16
# 151       nissan      pathfinder 4wd    3.3  1999    6  manual(m5)   4   15
# 55         dodge   dakota pickup 4wd    5.2  1999    8  manual(m5)   4   11
# 74          ford      expedition 2wd    4.6  1999    8    auto(l4)   r   11
# ..           ...                 ...    ...   ...  ...         ...  ..  ...
# 10          audi          a4 quattro    2.0  2008    4    auto(s6)   4   19
# 24     chevrolet            corvette    5.7  1999    8    auto(l4)   r   15
# 46         dodge         caravan 2wd    3.8  2008    6    auto(l6)   f   16
# 122         jeep  grand cherokee 4wd    3.0  2008    6    auto(l5)   4   17
# 81          ford        explorer 4wd    4.6  2008    8    auto(l6)   4   13
#
# ...

# %%
mpg['test'].value_counts()
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
mpg['test'].unique()
# Out:
# array(['pass', 'fail'], dtype=object)

# %%
count_test = mpg['test'].value_counts()

# %%
type(count_test)
# Out:
# pandas.core.series.Series

# %%
count_test.plot.bar();

# %%
sns.countplot(mpg, x="test")
# Out:
# <Axes: xlabel='test', ylabel='count'>

# %%
sns.countplot(data=mpg,x="test",hue="category", stat="percent");

# %% [markdown]
# # 종합 조건문 활용하기

# %%
mpg['grade']=np.where(mpg['total']>=32, 'A',
             np.where(mpg['total']>=32,'B','C'))


mpg.sample(5)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 124         jeep  grand cherokee 4wd    4.0  1999    6    auto(l4)   4   15
# 206       toyota   toyota tacoma 4wd    4.0  2008    6    auto(l5)   4   16
# 183       toyota               camry    3.0  1999    6    auto(l4)   f   18
# 223   volkswagen          new beetle    2.0  1999    4  manual(m5)   f   21
# 86          ford     f150 pickup 4wd    4.6  1999    8    auto(l4)   4   13
#
#      hwy fl    category  total      mean  max  mpg_mean  test grade
# 124   20  r         suv     35  0.149573  NaN      17.5  fail     A
# 206   20  r      pickup     36  0.153846  NaN      18.0  fail     A
# 183   26  r     midsize     44  0.188034  NaN      22.0  pass     A
# 223   29  r  subcompact     50  0.213675  NaN      25.0  pass     A
# 86    16  r      pickup     29  0.123932  NaN      14.5  fail     C

# %%
count_grade=mpg['grade'].value_counts()
count_grade
# Out:
# A    128
# C    106
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot=0);

# %%
sns.countplot(mpg, x= "grade", hue="grade", stat="percent");

# %%
count_grade=mpg['grade'].value_counts().sort_index()

count_grade
# Out:
# A    128
# C    106
# Name: grade, dtype: int64

# %%
sns.countplot(mpg, x="grade", hue="grade", order=np.sort(mpg['grade'].unique()));

# %%
count_grade.plot.bar(rot=0)
# Out:
# <Axes: >

# %% [markdown]
# # 메서드 체이닝

# %%
s = mpg['grade']
s= s.value_counts()
s = s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
s = mpg['grade'].value_counts().sort_values()
s
# Out:
# C     60
# A    174
# Name: grade, dtype: int64

# %%
mpg['grade'].value_counts().sort_values()
# Out:
# C     60
# A    174
# Name: grade, dtype: int64

# %%
mpg['grade'].value_counts().sort_values(ascending=False)
# Out:
# A    174
# C     60
# Name: grade, dtype: int64

# %%
mpg['grade2']=np.where(mpg['total']>=30,'A',
                np.where(mpg['total']>=25,'B',
                         np.where(mpg['total']>=20,'C','D')))

# %%
mpg.sample()
# Out:
#     manufacturer               model  displ  year  cyl     trans drv  cty  \
# 127         jeep  grand cherokee 4wd    4.7  2008    8  auto(l5)   4   14
#
#      hwy fl category  total      mean  max  mpg_mean  test grade grade2
# 127   19  r      suv     33  0.141026  NaN      16.5  fail     A      A

# %%
mpg.sample(50)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 193       toyota             corolla    1.8  1999    4    auto(l3)   f   24
# 160       subaru        forester awd    2.5  1999    4    auto(l4)   4   18
# 37         dodge         caravan 2wd    2.4  1999    4    auto(l3)   f   18
# 117      hyundai             tiburon    2.0  2008    4  manual(m5)   f   20
# 181       toyota               camry    2.4  2008    4  manual(m5)   f   21
# 129         jeep  grand cherokee 4wd    6.1  2008    8    auto(l5)   4   11
# 224   volkswagen          new beetle    2.0  1999    4    auto(l4)   f   19
# 105        honda               civic    1.8  2008    4    auto(l5)   f   25
# 142       nissan              altima    2.4  1999    4    auto(l4)   f   19
# 95          ford             mustang    4.6  1999    8  manual(m5)   r   15
# 145       nissan              altima    3.5  2008    6  manual(m6)   f   19
# ...

# %% [markdown]
# ### 연산자 |(or),  메소드 isin

# %%
mpg['size'] = np.where((mpg['category'] == 'compact') |
                       (mpg['category'] == 'subcompact') |
                       (mpg['category'] == '2seater'), 'small', 'large')

mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %%
mpg['size'] = np.where(mpg['category'].isin(['compact', 'subcompact', '2seater']), 'small', 'large')

mpg['size'].value_counts() ## 시험 예상 문제
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #정리하기

# %%
# 1. 패키지 로드
import pandas as pd
import numpy as np

# 2. 데이터 불러오기
mpg = pd.read_csv('data/mpg.csv')

# 3. 데이터 파악하기
mpg.shape       # 행, 열 수
mpg.head()      # 데이터 앞부분
mpg.tail()      # 데이터 뒷부분
mpg.info()      # 속성
mpg.describe()  # 요약 통계량

# 4. 변수명 바꾸기
mpg = mpg.rename(columns = {'manufacturer' : 'company'})

# 5. 파생변수 만들기
mpg['total'] = (mpg['cty'] + mpg['hwy'])/2                  # 변수 조합
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')  # 조건문 활용

# 6. 빈도 확인하기
count_test = mpg['test'].value_counts()  # 빈도표 만들기
count_test.plot.bar(rot = 0)             # 빈도 막대 그래프 만들기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB
# <Axes: >
