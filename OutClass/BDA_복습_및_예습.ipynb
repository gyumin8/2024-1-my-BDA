# %% [markdown]
# <a href="https://colab.research.google.com/github/gyumin8/2024-1-my-BDA/blob/main/OutClass/BDA_%EB%B3%B5%EC%8A%B5_%EB%B0%8F_%EC%98%88%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CH3

# %%
var=[1,2,3]

# %%
var
# Out:
# [1, 2, 3]

# %%
var2=[4.5.6]
# Out:
#   File "<ipython-input-3-0cf45bf32cd2>", line 1
#     var2=[4.5.6]
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
var2=[4,5,6]

# %%
var1+var2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-742fb31e147b> in <cell line: 1>()
# ----> 1 var1+var2
#
# NameError: name 'var1' is not defined

# %%
x=[1,2,3]

# %%
sum(x)
max(x)
min(x)
# Out:
# 1

# %%
sum(x)
# Out:
# 6

# %%
max(x)
# Out:
# 3

# %%
min(x)
# Out:
# 1

# %%
import seaborn
var = ['a','a','b','c']
var
# Out:
# ['a', 'a', 'b', 'c']

# %%
seaborn.countplot(x=var)
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(data=df,x='sex');

# %%
sns.countplot(data=df, x='class')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(data=df, x='class', hue='alive')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(data=df, y='class', hue='alive')
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %% [markdown]
# #CH4

# %%
import pandas as pd

df=pd.DataFrame({'name' : ['김지훈','이유진','박동현','김민지'], 'english' : [90,80,60,70], 'math' : [50,60,100,20]})
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df['english']
# Out:
# 0    90
# 1    80
# 2    60
# 3    70
# Name: english, dtype: int64

# %%
df_csv_exam = pd.read_csv('sample_data/exam.csv')
df_csv_exam
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
df_midterm = pd.DataFrame({'english' : [90,80,60,70], 'math' : [50,60,100,20], 'nclass' : [1,1,2,2]})
df_midterm
# Out:
#    english  math  nclass
# 0       90    50       1
# 1       80    60       1
# 2       60   100       2
# 3       70    20       2

# %%
df_midterm.to_csv('sample_data/output_newdata.csv')

# %%
exam=pd.read_csv('sample_data/exam.csv')

# %% [markdown]
# #CH5

# %%
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.head(10)
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.tail()
# Out:
#    id  nclass  math  english  science
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.info
# Out:
# <bound method DataFrame.info of    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25>

# %%
exam.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-234b13666480> in <cell line: 1>()
# ----> 1 exam.shape()
#
# TypeError: 'tuple' object is not callable

# %%
exam.shape
# Out:
# (8, 5)

# %%
exam.describe()
# Out:
#             id    nclass      math   english   science
# count  8.00000  8.000000   8.00000   8.00000   8.00000
# mean   4.50000  1.500000  53.75000  89.50000  59.87500
# std    2.44949  0.534522  22.48015   7.89213  21.86607
# min    1.00000  1.000000  25.00000  78.00000  25.00000
# 25%    2.75000  1.000000  41.25000  84.50000  48.75000
# 50%    4.50000  1.500000  50.00000  89.50000  59.00000
# 75%    6.25000  2.000000  65.00000  97.25000  68.25000
# max    8.00000  2.000000  90.00000  98.00000  98.00000

# %%
df_raw=pd.DataFrame({'var1' : [1,2,1], 'var2' : [2,3,2]})

# %%
df_raw
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %%
df_new=df_raw.copy()

# %%
df_new
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %%
df_new=df_new.rename(columns = {'var2' : 'v2'})
df_new
# Out:
#    var1  v2
# 0     1   2
# 1     2   3
# 2     1   2

# %%
df=pd.DataFrame({'var1' : [4,3,8], 'var2' : [2,6,1]})

# %%
df['var_sum']=df['var1']+df['var2']
df
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       NaN
# 1     3     6        9       NaN
# 2     8     1        9       NaN

# %%
df['var_mean'] = (df['var1'] + df['var2'])/2
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %% [markdown]
# #CH6

# %%
exam
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('nclass==1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass!=2')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('math>50')
# Out:
#    id  nclass  math  english  science
# 1   2       1    60       97       60
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('math'<50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-d02f731006a9> in <cell line: 1>()
# ----> 1 exam.query('math'<50)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
exam.query('nclass == 1 | english >=80')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45

# %%
exam.query('nclass in [1,3,5]')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
nclass1=exam.query('nclass==1')
nclass1['math'].mean()
# Out:
# 46.25

# %%
nclass1_mean=nclass1['math'].mean()

# %%
nclass1_mean
# Out:
# 46.25

# %%
exam['math']
# Out:
# 0    50
# 1    60
# 2    45
# 3    30
# 4    25
# 5    50
# 6    80
# 7    90
# Name: math, dtype: int64

# %%
math=exam['math']

# %%
exam[['math']]
# Out:
#    math
# 0    50
# 1    60
# 2    45
# 3    30
# 4    25
# 5    50
# 6    80
# 7    90

# %%
exam.query('math>=50')[['id','math']].head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
exam.sort_values(['nclass', 'math'], ascending = [True, False])
# Out:
#    id  nclass  math  english  science
# 1   2       1    60       97       60
# 0   1       1    50       98       50
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 7   8       2    90       78       25
# 6   7       2    80       90       45
# 5   6       2    50       89       98
# 4   5       2    25       80       65

# %%
exam.assign(total = math+exam['english'] + exam['science'])
# Out:
#    id  nclass  math  english  science  total
# 0   1       1    50       98       50    198
# 1   2       1    60       97       60    217
# 2   3       1    45       86       78    209
# 3   4       1    30       98       58    186
# 4   5       2    25       80       65    170
# 5   6       2    50       89       98    237
# 6   7       2    80       90       45    215
# 7   8       2    90       78       25    193

# %%
import numpy as np
exam.assign(test=np.where(exam['science']>=60, 'pass', 'fall'))
# Out:
#    id  nclass  math  english  science  test
# 0   1       1    50       98       50  fall
# 1   2       1    60       97       60  pass
# 2   3       1    45       86       78  pass
# 3   4       1    30       98       58  fall
# 4   5       2    25       80       65  pass
# 5   6       2    50       89       98  pass
# 6   7       2    80       90       45  fall
# 7   8       2    90       78       25  fall

# %%
exam.assign(new = lambda x : x['math'] + x['english']+x['science'])
# Out:
#    id  nclass  math  english  science  new
# 0   1       1    50       98       50  198
# 1   2       1    60       97       60  217
# 2   3       1    45       86       78  209
# 3   4       1    30       98       58  186
# 4   5       2    25       80       65  170
# 5   6       2    50       89       98  237
# 6   7       2    80       90       45  215
# 7   8       2    90       78       25  193

# %%
exam.groupby('nclass')\
.agg(mean_math = ('math','mean'),
sum_math=('math','sum'),
median_math=('math','median'),
n=('nclass','count'))
# Out:
#         mean_math  sum_math  median_math  n
# nclass
# 1           46.25       185         47.5  4
# 2           61.25       245         65.0  4

# %%
exam.groupby('nclass').mean()
# Out:
#          id   math  english  science
# nclass
# 1       2.5  46.25    94.75    61.50
# 2       6.5  61.25    84.25    58.25
