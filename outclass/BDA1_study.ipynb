# %% [markdown]
# <a href="https://colab.research.google.com/github/gyumin8/2024-1-my-BDA/blob/main/outclass/BDA1_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 4.00 MiB | 4.95 MiB/s, done.

# %%
import pandas as pd

df=pd.read_csv('data/exam.csv')
df
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df['english']
# Out:
# 0     98
# 1     97
# 2     86
# 3     98
# 4     80
# 5     89
# 6     90
# 7     78
# 8     98
# 9     98
# 10    65
# 11    85
# 12    98
# 13    87
# 14    56
# 15    98
# 16    68
# 17    78
# 18    68
# 19    83
# Name: english, dtype: int64

# %%
df['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
len('exam.csv')
# Out:
# 8

# %%
df=pd.DataFrame({'name' : ['김지훈', '이유진', '박동현', '김민지'],
                 'english' : [90,80,60,70],
                 'math' : [50,60,100,20]}) #데이터 프레임 제작
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
#csv 불러오기
import pandas as pd

df_csv = pd.read_csv('data/exam.csv')

df_csv
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# -------------------------
# #5) 데이터 분석 기초

# %%
import pandas as pd  #데이터 다루기에 유용
import numpy as np #수치연산에 유용

#2 데이터 불러오기
mpg=pd.read_csv('data/mpg.csv')

# %%
#3 데이터 파악하기
mpg.head() #위에서부터 5행
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.tail() #아래에서부터 5행
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.shape # 234행 11열로 이루어짐 #shape는 메서드가 아닌 어트리뷰트
# Out:
# (234, 11)

# %%
mpg.info() #mpg의 정보
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe() #요약 통계량
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.describe(include = "all") #숫자가 아닌 문자도 표기
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %%
#4 변수명 바꾸기
mpg=mpg.rename(columns={'manufacturer':'company'}) #manufactrer -> company로 바뀜

mpg
# Out:
#         company   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0          audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1          audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2          audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3          audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4          audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229  volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230  volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231  volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232  volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233  volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
#5 파생변수 만들기

mpg['total']=(mpg['cty'] + mpg['hwy'])/2
mpg['test']=np.where(mpg['total']>=20,'pass','fail')

# %%
#6 빈도 확인하기

count_test = mpg['test'].value_counts()

# %%
count_test.plot.bar()
# Out:
# <Axes: xlabel='test'>

# %%
count_test.plot.bar(rot=0)
# Out:
# <Axes: xlabel='test'>

# %% [markdown]
# -----------------------------------------------
# #6) 데이터 가공하기

# %% [markdown]
# - 데이터 전처리 : 데이터를 분석에 적합하게 가공 \
# - pandas : 데이터 전처리에 매우 유용한 패키지

# %%
import pandas as pd
exam= pd.read_csv('data/exam.csv')

# %%
## 1. 조건에 맞는 데이터만 추출
exam.query('english<=80')
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %%
#여러 조건 동시 충족
exam.query('nclass ==1 & math>=50')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
#여러 조건 중 하나 이상 충족
exam.query('math >= 90 | english >=90')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 12  13       4    46       98       65
# 15  16       4    58       98       65

# %%
exam.query('nclass in [1,3,5]') #in은 안에 있는 조건에 부합하는지 확인후 추출
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
## 2. 필요한 변수만 추출
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam[['nclass','math','english']]
# Out:
#     nclass  math  english
# 0        1    50       98
# 1        1    60       97
# 2        1    45       86
# 3        1    30       98
# 4        2    25       80
# 5        2    50       89
# 6        2    80       90
# 7        2    90       78
# 8        3    20       98
# 9        3    50       98
# 10       3    65       65
# 11       3    45       85
# 12       4    46       98
# 13       4    48       87
# 14       4    75       56
# 15       4    58       98
# 16       5    65       68
# 17       5    80       78
# 18       5    89       68
# 19       5    78       83

# %%
exam['nclass','math','english'] #괄호가 하나 더 없으면 오류
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('nclass', 'math', 'english')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
exam.drop(columns = 'math')
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam.drop('math') #columns = 'math' 필수
# Out:
#   File "<ipython-input-54-a49a0f747298>", line 1
#     exam.drop('math') //columns = 'math' 필수
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
exam.drop(columns=['math','english'])
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
## 3. pandas 명령어 조합하기
exam.query('math>=50')[['id','math']].head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
## 4. 순서대로 정렬하기
exam.sort_values('math')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
exam.sort_values('math',ascending=False) #내림차순 정렬
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 0    1       1    50       98       50
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
# 여러 변수 기준 정렬
exam.sort_values(['nclass','math'],ascending=[True,False]) #nclass는 오름차순 math 내림차순 정렬
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 8    9       3    20       98       15
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 16  17       5    65       68       98

# %%
## 5. 파생변수 추가하기
exam.assign(total=exam['math']+exam['english'] + exam['science'])
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
#여러 파생변수 한 번에 추가하기
exam.assign(total=exam['math']+exam['english']+exam['science'],
            mean =(exam['math']+exam['english']+exam['science'])/3)
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %%
# assign()에 np.where() 적용하기
exam.assign(test = np.where(exam['science']>=60, 'pass','fail'))
# Out:
#     id  nclass  math  english  science  test
# 0    1       1    50       98       50  fail
# 1    2       1    60       97       60  pass
# 2    3       1    45       86       78  pass
# 3    4       1    30       98       58  fail
# 4    5       2    25       80       65  pass
# 5    6       2    50       89       98  pass
# 6    7       2    80       90       45  fail
# 7    8       2    90       78       25  fail
# 8    9       3    20       98       15  fail
# 9   10       3    50       98       45  fail
# 10  11       3    65       65       65  pass
# 11  12       3    45       85       32  fail
# 12  13       4    46       98       65  pass
# 13  14       4    48       87       12  fail
# 14  15       4    75       56       78  pass
# 15  16       4    58       98       65  pass
# 16  17       5    65       68       98  pass
# 17  18       5    80       78       90  pass
# 18  19       5    89       68       87  pass
# 19  20       5    78       83       58  fail

# %%
# 추가한 변수를 pandas 코드에 바로 활용
exam.assign(total = exam['math']+exam['english']+exam['science'])\
  .sort_values('total')\
  .head()
# Out:
#     id  nclass  math  english  science  total
# 8    9       3    20       98       15    133
# 13  14       4    48       87       12    147
# 11  12       3    45       85       32    162
# 4    5       2    25       80       65    170
# 3    4       1    30       98       58    186

# %%
## 6. 집단별로 요약하기
exam.groupby('nclass')\
    .agg(mean_math=('math','mean'))
# Out:
#         mean_math
# nclass
# 1           46.25
# 2           61.25
# 3           45.00
# 4           56.75
# 5           78.00

# %%
# 각 집단별로 다시 집단 나누기
mpg.groupby(['company','drv'])\
  .agg(mean_cty=('cty','mean'))
# Out:
#                  mean_cty
# company    drv
# audi       4    16.818182
#            f    18.857143
# chevrolet  4    12.500000
#            f    18.800000
#            r    14.100000
# dodge      4    12.000000
#            f    15.818182
# ford       4    13.307692
#            r    14.750000
# honda      f    24.444444
# hyundai    f    18.642857
# jeep       4    13.500000
# land rover 4    11.500000
# lincoln    r    11.333333
# mercury    4    13.250000
# nissan     4    13.750000
#            f    20.000000
# pontiac    f    17.000000
# subaru     4    19.285714
# toyota     4    14.933333
#            f    21.368421
# volkswagen f    20.925926

# %%
## 7. 데이터 합치기
pd.merge(test1, test2, how = 'left', on='id') #가로로 합치기 , 왼쪽으로 , id를 기준으로

# %%
pd.concat([group_a, group_b]) #세로로 합치기
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-aad46d5bd732> in <cell line: 1>()
# ----> 1 pd.concat([group_a, group_b]) #세로로 합치기
#
# NameError: name 'group_a' is not defined

# %% [markdown]
# -----------------------------
# #7) 데이터 정제

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df =pd.DataFrame({'sex' : ['M','F',np.nan,'M','F'],
                  'score' : [5,4,3,4,np.nan]})

df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
## 1. 결측치 정제하기
pd.isna(df).sum() #결측치 확인
# Out:
# sex      1
# score    1
# dtype: int64

# %%
pd.isna(df)
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df_nomiss = df.dropna(subset = ['score']) #결측치 제거

# %%
df_nomiss = df.dropna(subset = ['score','sex']) #여러 변수 동시에 결측치 제거

# %%
## 2. 이상치 정제하기

# 이상치 확인
df['sex'].value_counts()
# Out:
# sex
# M    2
# F    2
# Name: count, dtype: int64

# %%
df['sex'].value_counts().sort_index()
# Out:
# sex
# F    2
# M    2
# Name: count, dtype: int64

# %%
#이상치 결측 처리
df['sex'] = np.where(df['sex'] == 3, np.nan,df['sex'])

# %%
#상자 그림으로 극단치 기준 찾기
pct25 = mpg['hwy'].quantile(.25) #1사분위수
pct75 = mpg['hwy'].quantile(.75) #3사분위수
iqr = pct75- pct25 #IQR 중간
pct25-1.5*iqr #하한
pct75+1.5*iqr #상한
# Out:
# 40.5

# %%
sns.boxplot(data=mpg, y='hwy')
# Out:
# <Axes: ylabel='hwy'>

# %%
#극단치 결측 처리

mpg['hwy'] = np.where((mpg['hwy']<4.5) | (mpg['hwy']>40.5),
                       np.nan, mpg['hwy'])

# %%
mpg['hwy']
# Out:
# 0      29.0
# 1      29.0
# 2      31.0
# 3      30.0
# 4      26.0
#        ...
# 229    28.0
# 230    29.0
# 231    26.0
# 232    26.0
# 233    26.0
# Name: hwy, Length: 234, dtype: float64

# %%
sns.boxplot(data=mpg, y='hwy')
# Out:
# <Axes: ylabel='hwy'>
